# %%
#preprocessing the dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d=pd.read_csv("C:\\Users\\ELCOT\\Documents\\house price data set.csv")

# %%
d.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# min      370.000000  5.200000e+02          1.000000            0.000000
# 25%     1440.000000  5.010750e+03          1.000000            0.000000
# 50%     1930.000000  7.620000e+03          1.500000            0.000000
# 75%     2570.000000  1.080000e+04          2.000000            0.000000
# max    13540.000000  1.074218e+06          3.500000            1.000000
#
#        number of views  condition of the house  ...    Built Year  \
# count     14620.000000            14620.000000  ...  14620.000000
# mean          0.233105                3.430506  ...   1970.926402
# std           0.766259                0.664151  ...     29.493625
# min           0.000000                1.000000  ...   1900.000000
# 25%           0.000000                3.000000  ...   1951.000000
# 50%           0.000000                3.000000  ...   1975.000000
# 75%           0.000000                4.000000  ...   1997.000000
# max           4.000000                5.000000  ...   2015.000000
#
#        Renovation Year    Postal Code     Lattitude     Longitude  \
# count     14620.000000   14620.000000  14620.000000  14620.000000
# mean         90.924008  122033.062244     52.792848   -114.404007
# std         416.216661      19.082418      0.137522      0.141326
# min           0.000000  122003.000000     52.385900   -114.709000
# 25%           0.000000  122017.000000     52.707600   -114.519000
# 50%           0.000000  122032.000000     52.806400   -114.421000
# 75%           0.000000  122048.000000     52.908900   -114.315000
# max        2015.000000  122072.000000     53.007600   -113.505000
#
#        living_area_renov  lot_area_renov  Number of schools nearby  \
# count       14620.000000    14620.000000              14620.000000
# mean         1996.702257    12753.500068                  2.012244
# std           691.093366    26058.414467                  0.817284
# min           460.000000      651.000000                  1.000000
# 25%          1490.000000     5097.750000                  1.000000
# 50%          1850.000000     7620.000000                  2.000000
# 75%          2380.000000    10125.000000                  3.000000
# max          6110.000000   560617.000000                  3.000000
#
#        Distance from the airport         Price
# count               14620.000000  1.462000e+04
# mean                   64.950958  5.389322e+05
# std                     8.936008  3.675324e+05
# min                    50.000000  7.800000e+04
# 25%                    57.000000  3.200000e+05
# 50%                    65.000000  4.500000e+05
# 75%                    73.000000  6.450000e+05
# max                    80.000000  7.700000e+06
#
# [8 rows x 23 columns]

# %%
df=d.dropna()

# %%
d.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# dtype: int64

# %%
x=pd.DataFrame(d.iloc[:,2:22].values)
y=d.iloc[:,22].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#Build the ANN model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
classifier=Sequential()

# %%
#input layer,2 hidden layer,output layer
classifier.add(Dense(19,activation='relu'))
classifier.add(Dense(15,activation='relu'))
classifier.add(Dense(29,activation='relu'))
classifier.add(Dense(3,activation='linear'))

# %%
classifier.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
#Train the model
classifier.fit(x_train,y_train,batch_size=10,epochs=25)
# Out:
# Epoch 1/25
# 1170/1170 [==============================] - 15s 9ms/step - loss: 343637360640.0000 - mse: 343637360640.0000
# Epoch 2/25
# 1170/1170 [==============================] - 6s 5ms/step - loss: 74703101952.0000 - mse: 74703101952.0000
# Epoch 3/25
# 1170/1170 [==============================] - 7s 6ms/step - loss: 53638549504.0000 - mse: 53638549504.0000
# Epoch 4/25
# 1170/1170 [==============================] - 6s 5ms/step - loss: 46548213760.0000 - mse: 46548213760.0000
# Epoch 5/25
# 1170/1170 [==============================] - 7s 6ms/step - loss: 41403031552.0000 - mse: 41403031552.0000
# Epoch 6/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 38338412544.0000 - mse: 38338412544.0000
# Epoch 7/25
# 1170/1170 [==============================] - 10s 8ms/step - loss: 36300038144.0000 - mse: 36300038144.0000
# Epoch 8/25
# 1170/1170 [==============================] - 9s 8ms/step - loss: 35075371008.0000 - mse: 35075371008.0000
# Epoch 9/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 34282213376.0000 - mse: 34282213376.0000
# Epoch 10/25
# 1170/1170 [==============================] - 9s 7ms/step - loss: 33547339776.0000 - mse: 33547339776.0000
# Epoch 11/25
# 1170/1170 [==============================] - 8s 7ms/step - loss: 33117235200.0000 - mse: 33117235200.0000
# Epoch 12/25
# 1170/1170 [==============================] - 9s 7ms/step - loss: 32758554624.0000 - mse: 32758554624.0000
# Epoch 13/25
# 1170/1170 [==============================] - 9s 8ms/step - loss: 32421507072.0000 - mse: 32421507072.0000
# Epoch 14/25
# 1170/1170 [==============================] - 9s 8ms/step - loss: 32141154304.0000 - mse: 32141154304.0000
# Epoch 15/25
# 1170/1170 [==============================] - 11s 9ms/step - loss: 31861530624.0000 - mse: 31861530624.0000
# Epoch 16/25
# 1170/1170 [==============================] - 10s 8ms/step - loss: 31663804416.0000 - mse: 31663804416.0000
# Epoch 17/25
# 1170/1170 [==============================] - 9s 7ms/step - loss: 31458641920.0000 - mse: 31458641920.0000
# Epoch 18/25
# 1170/1170 [==============================] - 9s 8ms/step - loss: 31230707712.0000 - mse: 31230707712.0000
# Epoch 19/25
# 1170/1170 [==============================] - 9s 7ms/step - loss: 31087722496.0000 - mse: 31087722496.0000
# Epoch 20/25
#  853/1170 [====================>.........] - ETA: 2s - loss: 32707375104.0000 - mse: 32707375104.0000

# %%
#Test the model
y_pred=classifier.predict(x_test)
y_pred=(y_pred>0.5)
# Out:
# 92/92 [==============================] - 1s 7ms/step
